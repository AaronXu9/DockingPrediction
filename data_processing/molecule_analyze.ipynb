# %%
import umap
# import umap.umap_ as umap
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import PandasTools
from matplotlib import pyplot as plt

# Load the molecule graphs from the files
file1 = '../../data/train_100K.sdf'
file2 = '../../data/D2_7jvr_dop_393b_2comp_final_10M_test_10K.sdf'

# Read the molecule graphs from the files
mols1 = PandasTools.LoadSDF(file1)
mols2 = PandasTools.LoadSDF(file2)

# Generate the molecular fingerprints for each set of molecule graphs
fps1 = [AllChem.GetMorganFingerprintAsBitVect(mol, 2) for mol in mols1['ROMol']]
fps2 = [AllChem.GetMorganFingerprintAsBitVect(mol, 2) for mol in mols2['ROMol']]

# Convert the fingerprints to numpy arrays
X1 = np.array(fps1)
X2 = np.array(fps2)

# %%
file3 = '../results/test_1M_results.sdf'
mol3 = PandasTools.LoadSDF(file3)
fps3 = [AllChem.GetMorganFingerprintAsBitVect(mol, 2) for mol in mol3['ROMol']]
X3 = np.array(fps3)
# Out:
# [14:22:59] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:23:10] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:23:25] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:23:34] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:23:46] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:24:05] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 25 ignored
# [14:24:32] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:24:44] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:24:51] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:25:16] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:25:37] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 20 ignored
# [14:25:48] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 24 ignored
# [14:26:24] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:26:29] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:26:37] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:26:46] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:26:58] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:28:20] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 25 ignored
# [14:28:21] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:28:30] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:28:31] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:28:33] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:28:44] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:28:59] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 9 ignored
# [14:29:11] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:29:16] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 23 ignored
# [14:29:16] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:29:23] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 22 ignored
# [14:29:24] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:29:39] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:29:41] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:29:42] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 25 ignored
# [14:29:47] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:30:17] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:30:25] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:30:35] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:30:47] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:30:57] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 17 ignored
# [14:31:02] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:31:23] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:31:27] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:31:31] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:31:42] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:31:44] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:31:51] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:31:58] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:32:20] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 9 ignored
# [14:32:43] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:32:52] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:33:58] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:34:04] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:34:25] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:34:43] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:34:55] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:35:17] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:35:29] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:35:54] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:36:11] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:36:26] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:37:03] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:37:25] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 9 ignored
# [14:37:58] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 9 ignored
# [14:38:01] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:38:12] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:38:25] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:38:36] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:38:44] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:38:46] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:39:07] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:39:09] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:39:24] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:39:39] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:39:56] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:40:10] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:40:24] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 9 ignored
# [14:40:34] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:40:35] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 22 ignored
# [14:40:36] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:40:40] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:40:42] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:40:48] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:40:53] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:41:32] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:41:37] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:41:50] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:42:46] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:42:46] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:43:07] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 25 ignored
# [14:43:08] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:43:11] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:43:20] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:43:24] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:43:59] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:43:59] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:45:04] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:45:10] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:45:24] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:45:34] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 9 ignored
# [14:45:51] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 24 ignored
# [14:46:02] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:46:16] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:46:32] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:46:35] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:46:36] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:46:39] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:46:49] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:47:06] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:47:10] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:47:24] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:48:11] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:48:20] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 15 ignored
# [14:48:30] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:48:30] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:48:32] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:48:42] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:49:02] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:49:02] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 21 ignored
# [14:49:12] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:49:37] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:49:44] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:49:49] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:49:59] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:50:01] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:50:18] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:50:20] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 18 ignored
# [14:50:38] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:51:24] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:51:31] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:51:53] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:51:54] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:52:02] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:52:22] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:52:48] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:52:58] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:53:00] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 10 ignored
# [14:53:07] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:53:09] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:53:14] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:53:17] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:53:44] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:54:02] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:55:01] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 11 ignored
# [14:55:12] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 9 ignored
# [14:55:17] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:55:27] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:56:00] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:57:07] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:57:21] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [14:57:41] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [14:57:48] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [14:58:01] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [14:58:14] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [14:58:22] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 25 ignored
# [14:59:16] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 26 ignored
# [14:59:46] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 10 ignored
# [14:59:57] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [15:00:05] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [15:00:17] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [15:00:26] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [15:00:28] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [15:00:28] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [15:00:40] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [15:00:44] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [15:00:52] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [15:00:52] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [15:00:56] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [15:01:01] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [15:01:06] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 24 ignored
# [15:01:34] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 22 ignored
# [15:01:56] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [15:02:03] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 5 ignored
# [15:02:05] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [15:02:09] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [15:02:41] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [15:02:48] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 24 ignored
# [15:02:50] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [15:03:01] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [15:04:00] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 22 ignored
# [15:04:05] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [15:04:51] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [15:04:58] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [15:05:00] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [15:05:25] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [15:05:31] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [15:05:36] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [15:05:54] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [15:06:00] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 9 ignored
# [15:06:21] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 6 ignored
# [15:06:31] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 4 ignored
# [15:06:33] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 10 ignored
# [15:06:40] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 7 ignored
# [15:07:24] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 8 ignored
# [15:07:49] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 19 ignored

# %%
# Perform dimensionality reduction using UMAP
reducer = umap.UMAP()

# Fit the reducer on the combined dataset to get the transformation, then transform separately
combined_X = np.vstack((X1, X2, X3))
reducer.fit(combined_X)

embedding1 = reducer.transform(X1)
embedding2 = reducer.transform(X2)
embedding3 = reducer.transform(X3)

# Plot the 2D map with different colors
plt.scatter(embedding1[:, 0], embedding1[:, 1], c='red', label='File 1')
plt.scatter(embedding2[:, 0], embedding2[:, 1], c='blue', label='File 2')
plt.scatter(embedding3[:, 0], embedding3[:, 1], c='green', label='File 3')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.title('Molecule Graph Projection')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/aoxu/projects/DrugDiscovery/AL_Python/data_processing/molecule_analyze.ipynb Cell 3 line 6
#       <a href='vscode-notebook-cell:/Users/aoxu/projects/DrugDiscovery/AL_Python/data_processing/molecule_analyze.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> # Fit the reducer on the combined dataset to get the transformation, then transform separately
#       <a href='vscode-notebook-cell:/Users/aoxu/projects/DrugDiscovery/AL_Python/data_processing/molecule_analyze.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> combined_X = np.vstack((X1, X2, X3))
# ----> <a href='vscode-notebook-cell:/Users/aoxu/projects/DrugDiscovery/AL_Python/data_processing/molecule_analyze.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> reducer.fit(combined_X)
#       <a href='vscode-notebook-cell:/Users/aoxu/projects/DrugDiscovery/AL_Python/data_processing/molecule_analyze.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> embedding1 = reducer.transform(X1)
#       <a href='vscode-notebook-cell:/Users/aoxu/projects/DrugDiscovery/AL_Python/data_processing/molecule_analyze.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> embedding2 = reducer.transform(X2)
#
# File ~/miniconda3/envs/molpal/lib/python3.8/site-packages/umap/umap_.py:2780, in UMAP.fit(self, X, y, force_all_finite)
#    2776 if self.transform_mode == "embedding":
#    2777     epochs = (
#    2778         self.n_epochs_list if self.n_epochs_list is not None else self.n_epochs
#    2779     )
# -> 2780     self.embedding_, aux_data = self._fit_embed_data(
#    2781         self._raw_data[index],
#    2782         epochs,
#    2783         init,
#    2784         random_state,  # JH why raw data?
#    2785     )
#    2787     if self.n_epochs_list is not None:
#    2788         if "embedding_list" not in aux_data:
#
# File ~/miniconda3/envs/molpal/lib/python3.8/site-packages/umap/umap_.py:2826, in UMAP._fit_embed_data(self, X, n_epochs, init, random_state)
#    2822 def _fit_embed_data(self, X, n_epochs, init, random_state):
#    2823     """A method wrapper for simplicial_set_embedding that can be
#    2824     replaced by subclasses.
#    2825     """
# -> 2826     return simplicial_set_embedding(
#    2827         X,
#    2828         self.graph_,
#    2829         self.n_components,
#    2830         self._initial_alpha,
#    2831         self._a,
#    2832         self._b,
#    2833         self.repulsion_strength,
#    2834         self.negative_sample_rate,
#    2835         n_epochs,
#    2836         init,
#    2837         random_state,
#    2838         self._input_distance_func,
#    2839         self._metric_kwds,
#    2840         self.densmap,
#    2841         self._densmap_kwds,
#    2842         self.output_dens,
#    2843         self._output_distance_func,
#    2844         self._output_metric_kwds,
#    2845         self.output_metric in ("euclidean", "l2"),
#    2846         self.random_state is None,
#    2847         self.verbose,
#    2848         tqdm_kwds=self.tqdm_kwds,
#    2849     )
#
# File ~/miniconda3/envs/molpal/lib/python3.8/site-packages/umap/umap_.py:1106, in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1102     embedding = noisy_scale_coords(
#    1103         embedding, random_state, max_coord=10, noise=0.0001
#    1104     )
#    1105 elif isinstance(init, str) and init == "spectral":
# -> 1106     embedding = spectral_layout(
#    1107         data,
#    1108         graph,
#    1109         n_components,
#    1110         random_state,
#    1111         metric=metric,
#    1112         metric_kwds=metric_kwds,
#    1113     )
#    1114     # We add a little noise to avoid local minima for optimization to come
#    1115     embedding = noisy_scale_coords(
#    1116         embedding, random_state, max_coord=10, noise=0.0001
#    1117     )
#
# File ~/miniconda3/envs/molpal/lib/python3.8/site-packages/umap/spectral.py:304, in spectral_layout(data, graph, dim, random_state, metric, metric_kwds, tol, maxiter)
#     263 def spectral_layout(
#     264     data,
#     265     graph,
#    (...)
#     271     maxiter=0
#     272 ):
#     273     """
#     274     Given a graph compute the spectral embedding of the graph. This is
#     275     simply the eigenvectors of the laplacian of the graph. Here we use the
#    (...)
#     302         The spectral embedding of the graph.
#     303     """
# --> 304     return _spectral_layout(
#     305         data=data,
#     306         graph=graph,
#     307         dim=dim,
#     308         random_state=random_state,
#     309         metric=metric,
#     310         metric_kwds=metric_kwds,
#     311         init="random",
#     312         tol=tol,
#     313         maxiter=maxiter
#     314     )
#
# File ~/miniconda3/envs/molpal/lib/python3.8/site-packages/umap/spectral.py:467, in _spectral_layout(data, graph, dim, random_state, metric, metric_kwds, init, method, tol, maxiter)
#     464 n_components, labels = scipy.sparse.csgraph.connected_components(graph)
#     466 if n_components > 1:
# --> 467     return multi_component_layout(
#     468         data,
#     469         graph,
#     470         n_components,
#     471         labels,
#     472         dim,
#     473         random_state,
#     474         metric=metric,
#     475         metric_kwds=metric_kwds,
#     476     )
#     478 sqrt_deg = np.sqrt(np.asarray(graph.sum(axis=0)).squeeze())
#     479 # standard Laplacian
#     480 # D = scipy.sparse.spdiags(diag_data, 0, graph.shape[0], graph.shape[0])
#     481 # L = D - graph
#     482 # Normalized Laplacian
#
# File ~/miniconda3/envs/molpal/lib/python3.8/site-packages/umap/spectral.py:243, in multi_component_layout(data, graph, n_components, component_labels, dim, random_state, metric, metric_kwds, init, tol, maxiter)
#     234     result[component_labels == label] = (
#     235         random_state.uniform(
#     236             low=-data_range,
#    (...)
#     240         + meta_embedding[label]
#     241     )
#     242 else:
# --> 243     component_embedding = _spectral_layout(
#     244         data=None,
#     245         graph=component_graph,
#     246         dim=dim,
#     247         random_state=random_state,
#     248         metric=metric,
#     249         metric_kwds=metric_kwds,
#     250         init=init,
#     251         tol=tol,
#     252         maxiter=maxiter
#     253     )
#     254     expansion = data_range / np.max(np.abs(component_embedding))
#     255     component_embedding *= expansion
#
# File ~/miniconda3/envs/molpal/lib/python3.8/site-packages/umap/spectral.py:521, in _spectral_layout(data, graph, dim, random_state, metric, metric_kwds, init, method, tol, maxiter)
#     518 X[:, 0] = sqrt_deg / np.linalg.norm(sqrt_deg)
#     520 if method == "eigsh":
# --> 521     eigenvalues, eigenvectors = scipy.sparse.linalg.eigsh(
#     522         L,
#     523         k,
#     524         which="SM",
#     525         ncv=num_lanczos_vectors,
#     526         tol=tol or 1e-4,
#     527         v0=np.ones(L.shape[0]),
#     528         maxiter=maxiter or graph.shape[0] * 5,
#     529     )
#     530 elif method == "lobpcg":
#     531     with warnings.catch_warnings():
#
# File ~/miniconda3/envs/molpal/lib/python3.8/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:1697, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1695 with _ARPACK_LOCK:
#    1696     while not params.converged:
# -> 1697         params.iterate()
#    1699     return params.extract(return_eigenvectors)
#
# File ~/miniconda3/envs/molpal/lib/python3.8/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:537, in _SymmetricArpackParams.iterate(self)
#     535 def iterate(self):
#     536     self.ido, self.tol, self.resid, self.v, self.iparam, self.ipntr, self.info = \
# --> 537         self._arpack_solver(self.ido, self.bmat, self.which, self.k,
#     538                             self.tol, self.resid, self.v, self.iparam,
#     539                             self.ipntr, self.workd, self.workl, self.info)
#     541     xslice = slice(self.ipntr[0] - 1, self.ipntr[0] - 1 + self.n)
#     542     yslice = slice(self.ipntr[1] - 1, self.ipntr[1] - 1 + self.n)
#
# KeyboardInterrupt:
